# %% [markdown]
# <a href="https://colab.research.google.com/github/kjgeetasri/AIML-COLAB/blob/main/Randam_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-15d7c070-564c-4559-a2b8-7e57ef744ddf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15d7c070-564c-4559-a2b8-7e57ef744ddf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel('Model Sample Data - Retail Inventory.xlsx')

# %%
import pandas as pd

# The file 'Model Sample Data - Retail Inventory.xlsx' was uploaded.
df = pd.read_excel('Model Sample Data - Retail Inventory.xlsx')

display(df.head())
# Out:
#                             Store Location (i) Product  \
# 0                                            1      p1
# 1  Distance from Centralized Disposal Facility      p5
# 2                                          NaN      p8
# 3                                          NaN     p16
# 4                                          NaN     p17
#
#   Volume per unit of product (cm3) Beginning Inventory (Bipi, pc)  \
# 0                              469                             30
# 1                               72                            136
# 2                              366                             48
# 3                              393                             96
# 4                              121                             23
#
#   Lower Maintaining Inventory Level (LMILpi, pc)  \
# 0                                             47
# 1                                             20
# 2                                             49
# ...

# %%
df = pd.read_excel('Model Sample Data - Retail Inventory.xlsx')

# %%
display(df.describe())
# Out:
#        Unnamed: 16  \
# count      30.0000
# mean      795.0000
# std       361.1834
# min       400.0000
# 25%       500.0000
# 50%       660.0000
# 75%      1000.0000
# max      1500.0000
#
#        REMOVED PRODUCTS: 2,3,4,6,7,9,10,11,12,14,15,13,19,20,22,23, 24, 25, 26  \
# count                                           9.000000
# mean                                            3.333333
# std                                             2.500000
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             8.000000
#
#        Unnamed: 21
# count     9.000000
# mean      0.333333
# std       0.250000
# min       0.100000
# 25%       0.100000
# 50%       0.400000
# 75%       0.500000
# max       0.800000

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'Model Sample Data - Retail Inventory.xlsx', 'Model Sample Data - Retail Inventory (1).xlsx', 'sample_data']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'Model Sample Data - Retail Inventory.xlsx', 'Model Sample Data - Retail Inventory (1).xlsx', 'sample_data']

# %%
print("Missing values in each column:\n")
display(df.isnull().sum())
# Out:
# Missing values in each column:
# Store Location (i)                                                         18
# Product                                                                     3
# Volume per unit of product (cm3)                                            3
# Beginning Inventory (Bipi, pc)                                              3
# Lower Maintaining Inventory Level (LMILpi, pc)                              3
# Expected Maintaining Inventory Level (EMILpi, pc)                           3
# Upper Maintaining Inventory Level (UMILpi, pc)                              3
# Product category (from Phase 1)                                             3
# selling price (sp, Php/pc)                                                  3
# cost (cp, Php/pc)                                                           3
# disposal cost (disppi, Php/pc)                                              3
# transport cost (tpi, Php/pc)                                                3
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'Model Sample Data - Retail Inventory.xlsx', 'Model Sample Data - Retail Inventory (1).xlsx', 'sample_data']

# %%
import numpy as np

# %%
print("Descriptive statistics for numerical columns after conversion:")
display(df.describe())
# Out:
# Descriptive statistics for numerical columns after conversion:
#        Unnamed: 16  \
# count      30.0000
# mean      795.0000
# std       361.1834
# min       400.0000
# 25%       500.0000
# 50%       660.0000
# 75%      1000.0000
# max      1500.0000
#
#        REMOVED PRODUCTS: 2,3,4,6,7,9,10,11,12,14,15,13,19,20,22,23, 24, 25, 26  \
# count                                           9.000000
# mean                                            3.333333
# std                                             2.500000
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             8.000000
#
#        Unnamed: 21
# count     9.000000
# mean      0.333333
# std       0.250000
# min       0.100000
# 25%       0.100000
# 50%       0.400000
# 75%       0.500000
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c6672cec-e5d3-44f3-b5c5-9f00f77bc04d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6672cec-e5d3-44f3-b5c5-9f00f77bc04d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(os.listdir())
# Out:
# ['.config', 'Model Sample Data - Retail Inventory.xlsx', 'Model Sample Data - Retail Inventory (1).xlsx', 'Model Sample Data - Retail Inventory (2).xlsx', 'sample_data']

# %%
print("Missing values in each column:")
display(df.isnull().sum())
# Out:
# Missing values in each column:
# Store Location (i)                                                         18
# Product                                                                     3
# Volume per unit of product (cm3)                                            3
# Beginning Inventory (Bipi, pc)                                              3
# Lower Maintaining Inventory Level (LMILpi, pc)                              3
# Expected Maintaining Inventory Level (EMILpi, pc)                           3
# Upper Maintaining Inventory Level (UMILpi, pc)                              3
# Product category (from Phase 1)                                             3
# selling price (sp, Php/pc)                                                  3
# cost (cp, Php/pc)                                                           3
# disposal cost (disppi, Php/pc)                                              3
# transport cost (tpi, Php/pc)                                                3
# ...

# %%
print("Missing values in each column:")
display(df.isnull().sum())
# Out:
# Missing values in each column:
# Store Location (i)                                                         18
# Product                                                                     3
# Volume per unit of product (cm3)                                            3
# Beginning Inventory (Bipi, pc)                                              3
# Lower Maintaining Inventory Level (LMILpi, pc)                              3
# Expected Maintaining Inventory Level (EMILpi, pc)                           3
# Upper Maintaining Inventory Level (UMILpi, pc)                              3
# Product category (from Phase 1)                                             3
# selling price (sp, Php/pc)                                                  3
# cost (cp, Php/pc)                                                           3
# disposal cost (disppi, Php/pc)                                              3
# transport cost (tpi, Php/pc)                                                3
# ...

# %%
print("First 5 rows of the DataFrame:")
display(df.head())
# Out:
# First 5 rows of the DataFrame:
#                             Store Location (i) Product  \
# 0                                            1      p1
# 1  Distance from Centralized Disposal Facility      p5
# 2                                          NaN      p8
# 3                                          NaN     p16
# 4                                          NaN     p17
#
#   Volume per unit of product (cm3) Beginning Inventory (Bipi, pc)  \
# 0                              469                             30
# 1                               72                            136
# 2                              366                             48
# 3                              393                             96
# 4                              121                             23
#
#   Lower Maintaining Inventory Level (LMILpi, pc)  \
# 0                                             47
# 1                                             20
# 2                                             49
# ...

# %%
import os
import zipfile
import pandas as pd

# %%
print("First 5 rows of the DataFrame:")
display(df.head())
# Out:
# First 5 rows of the DataFrame:
#                             Store Location (i) Product  \
# 0                                            1      p1
# 1  Distance from Centralized Disposal Facility      p5
# 2                                          NaN      p8
# 3                                          NaN     p16
# 4                                          NaN     p17
#
#   Volume per unit of product (cm3) Beginning Inventory (Bipi, pc)  \
# 0                              469                             30
# 1                               72                            136
# 2                              366                             48
# 3                              393                             96
# 4                              121                             23
#
#   Lower Maintaining Inventory Level (LMILpi, pc)  \
# 0                                             47
# 1                                             20
# 2                                             49
# ...

# %%
print("DataFrame Info (data types and non-null counts):")
df.info()
# Out:
# DataFrame Info (data types and non-null counts):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 22 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Store Location (i)                                                       17 non-null     object
#  1   Product                                                                  32 non-null     object
#  2   Volume per unit of product (cm3)                                         32 non-null     object
#  3   Beginning Inventory (Bipi, pc)                                           32 non-null     object
#  4   Lower Maintaining Inventory Level (LMILpi, pc)                           32 non-null     object
#  5   Expected Maintaining Inventory Level (EMILpi, pc)                        32 non-null     object
# ...

# %%
print("Descriptive statistics for numerical columns:")
display(df.describe())
# Out:
# Descriptive statistics for numerical columns:
#        Unnamed: 16  \
# count      30.0000
# mean      795.0000
# std       361.1834
# min       400.0000
# 25%       500.0000
# 50%       660.0000
# 75%      1000.0000
# max      1500.0000
#
#        REMOVED PRODUCTS: 2,3,4,6,7,9,10,11,12,14,15,13,19,20,22,23, 24, 25, 26  \
# count                                           9.000000
# mean                                            3.333333
# std                                             2.500000
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             8.000000
#
#        Unnamed: 21
# count     9.000000
# mean      0.333333
# std       0.250000
# min       0.100000
# 25%       0.100000
# 50%       0.400000
# 75%       0.500000
# max       0.800000
